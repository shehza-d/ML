# %%
import pandas as pd
import numpy as np 
import matplotlib
import seaborn

# %%
# path= r"D:\new\customer_table_new.csv"

path2= r"D:\new\transaction_table_new.csv"
filet = r"transaction_table_new.csv"
file2= r"customer_table_new.csv"
df  = pd.read_csv(path2)
df_c =df.copy()

# pd.set_option('display.max_columns', 100)
# pd.set_option('display.max_rows', 100)
# Out:
# C:\Users\event\AppData\Local\Temp\ipykernel_11136\471884129.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df  = pd.read_csv(path2)

# %%
df.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
print(df.shape)
# Out:
# (584524, 25)

# %%
print(df.columns)
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Latitude', 'Longitude', 'City',
#        'phone_brand'],
#       dtype='object')

# %%
df.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
# Finding 
col= "status"
df_c[col].unique()
# Out:
# array(['complete', 'canceled', 'order_refunded', 'received', 'refund',
#        'closed', 'fraud', 'holded', 'exchange', 'pending_paypal', 'paid',
#        '\\N', 'cod', 'pending', nan, 'processing', 'payment_review'],
#       dtype=object)

# %%
#df_c[col] = df_c[col].str.replace('canceled','cancel')
df_c[col] = df_c[col].str.replace('cancel','canceled')
df_c[col].unique()
# Out:
# array(['complete', 'canceleded', 'order_refunded', 'received', 'refund',
#        'closed', 'fraud', 'holded', 'exchange', 'pending_paypal', 'paid',
#        '\\N', 'cod', 'pending', nan, 'processing', 'payment_review'],
#       dtype=object)

# %%
df_c[col] = df_c[col].str.replace('pend ing','pending')
df_c[col].unique()
# Out:
# array(['complete', 'canceleded', 'order_refunded', 'received', 'refund',
#        'closed', 'fraud', 'holded', 'exchange', 'pending_paypal', 'paid',
#        '\\N', 'cod', 'pending', nan, 'processing', 'payment_review'],
#       dtype=object)
